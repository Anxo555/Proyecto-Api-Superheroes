# %%
# Proyecto Api Superheroes
Enlace a la API https://superheroapi.com/

# %%
import requests
import json
import pandas as pd
Clave_Acceso = "82f72b70efe3582c843f7c2ea378986b"

# %%
def sacar_datos(heroes):
    url = f"https://superheroapi.com/api/{Clave_Acceso}/{heroes}"
    esponse = requests.get(url)
    
    try: 
        data = response.json()
        return data
    except: 
        return None

# %%
df = sacar_datos(644)
print(df)
# Out:
# None
