# %%
import requests

import pandas as pd
 
Clave_Acceso = "82f72b70efe3582c843f7c2ea378986b"
 
def obtener_heroes_completo(max_id=731, valor_faltante="Sin dato"):

    heroes_data = []
 
    for hero_id in range(1, max_id + 1):

        url = f"https://superheroapi.com/api/{Clave_Acceso}/{hero_id}"

        response = requests.get(url)

        if response.status_code == 200:

            data = response.json()

            if data.get("response") == "success":

                # Estadísticas

                stats = data.get("powerstats", {})

                # Apariencia

                appearance = data.get("appearance", {})

                # Biografía

                biography = data.get("biography", {})
 
                def parse_stat(value):

                    """Convierte a entero o retorna valor_faltante si no es un número válido"""

                    try:

                        return int(value)

                    except (ValueError, TypeError):

                        return valor_faltante
 
                hero = {

                    "ID": data.get("id", valor_faltante),

                    "Nombre": data.get("name", valor_faltante),

                    # Estadísticas convertidas a enteros

                    "Inteligencia": parse_stat(stats.get("intelligence", valor_faltante)),

                    "Fuerza": parse_stat(stats.get("strength", valor_faltante)),

                    "Velocidad": parse_stat(stats.get("speed", valor_faltante)),

                    "Durabilidad": parse_stat(stats.get("durability", valor_faltante)),

                    "Potencia": parse_stat(stats.get("power", valor_faltante)),

                    "Combate": parse_stat(stats.get("combat", valor_faltante)),

                    # Apariencia

                    "Genero": appearance.get("gender", valor_faltante),

                    "Etnia": appearance.get("race", valor_faltante),


                    "Altura_metric": appearance.get("height", ["Sin dato", "Sin dato"])[1] if len(appearance.get("height", [])) > 1 else "Sin dato",


                    "Peso_metric": appearance.get("weight", ["Sin dato", "Sin dato"])[1]if len(appearance.get("weight", [])) > 1 else "Sin dato",

                    "Color_Ojos": appearance.get("eye-color", valor_faltante),

                    "Color_Pelo": appearance.get("hair-color", valor_faltante),

                    # Biografía

                    "Nombre Completo": biography.get("full-name", valor_faltante),

                    "Alias": ", ".join(biography.get("aliases", [])) if biography.get("aliases") else valor_faltante,

                    "Lugar de nacimiento": biography.get("place-of-birth", valor_faltante),

                    "Primera aparición": biography.get("first-appearance", valor_faltante),

                    "Editor": biography.get("publisher", valor_faltante),

                    "Alineación": biography.get("alignment", valor_faltante)

                }
 
                heroes_data.append(hero)

            else:

                print(f"No se encontró héroe con ID {hero_id}")

        else:

            print(f"Error HTTP {response.status_code} para ID {hero_id}")
 
    df_heroes = pd.DataFrame(heroes_data)

   

    return df_heroes

# %%
# Out:
#    ID         Nombre Inteligencia Fuerza Velocidad Durabilidad  Potencia  \
# 0   1         A-Bomb           38    100        17          80        24
# 1   2     Abe Sapien           88     28        35          65       100
# 2   3       Abin Sur           50     90        53          64        99
# 3   4    Abomination           63     80        53          90        62
# 4   5        Abraxas           88     63        83         100       100
# 5   6  Absorbing Man           38     80        25         100        98
# 6   7    Adam Monroe           63     10        12         100       100
# 7   8   Adam Strange           69     10        33          40        37
# 8   9       Agent 13     Sin dato     46  Sin dato    Sin dato  Sin dato
# 9  10      Agent Bob           10      8        13           5         5
#
#     Combate  Genero              Etnia Altura_metric Peso_metric Color_Ojos  \
# 0        64    Male              Human        203 cm      441 kg     Yellow
# 1        85    Male      Icthyo Sapien        191 cm       65 kg       Blue
# 2        65    Male            Ungaran        185 cm       90 kg       Blue
# 3        95    Male  Human / Radiation        203 cm      441 kg      Green
# 4        55    Male      Cosmic Entity          0 cm        0 kg       Blue
# 5        64    Male              Human        193 cm      122 kg       Blue
# 6        64    Male               null          0 cm        0 kg       Blue
# 7        50    Male              Human        185 cm       88 kg       Blue
# 8  Sin dato  Female               null        173 cm       61 kg       Blue
# 9        20    Male              Human        178 cm       81 kg      Brown
#
#   Color_Pelo         Nombre Completo  \
# 0    No Hair  Richard Milhouse Jones
# 1    No Hair          Abraham Sapien
# 2    No Hair
# 3    No Hair            Emil Blonsky
# 4      Black                 Abraxas
# 5    No Hair              Carl Creel
# 6      Blond
# 7      Blond            Adam Strange
# 8      Blond           Sharon Carter
# 9      Brown                     Bob
#
#                                                Alias      Lugar de nacimiento  \
# 0                                         Rick Jones       Scarsdale, Arizona
# 1  Langdon Everett Caul, Abraham Sapien, Langdon ...                        -
# 2                                             Lagzia                   Ungara
# 3                       Agent R-7, Ravager of Worlds       Zagreb, Yugoslavia
# 4                                                  -          Within Eternity
# 5  Greithoth, "Crusher" Creel, Rocky Davis, Dynam...  New York City, New York
# 6                     Takezo Kensei, Richard Sanders                        -
# 7              Warrior of Two Worlds, Savior of Rann        Chicago, Illinois
# 8                                                  -                        -
# 9           Bob, agent of Hydra, Bob, agent of A.I.M                        -
#
#                              Primera aparición             Editor Alineación
# 0      Hulk Vol 2 #2 (April, 2008) (as A-Bomb)      Marvel Comics       good
# 1          Hellboy: Seed of Destruction (1993)  Dark Horse Comics       good
# 2                 Showcase #22 (October, 1959)          DC Comics       good
# 3                        Tales to Astonish #90      Marvel Comics        bad
# 4                  Fantastic Four Annual #2001      Marvel Comics        bad
# 5  Daredevil #1 (April, 1964) (As Rocky Davis)      Marvel Comics        bad
# 6         Heroes S02E01 - Four Months Later...       NBC - Heroes       good
# 7                   Outsiders #6 (April, 1986)          DC Comics       good
# 8                        Tales of Suspense #75      Sharon Carter       good
# 9             Cable & Deadpool #38 (May, 2007)      Marvel Comics       good

# %%
# Out:
#                                                  Alias           Nombre  \
# 0                                           Rick Jones           A-Bomb
# 1    Langdon Everett Caul, Abraham Sapien, Langdon ...       Abe Sapien
# 2                                               Lagzia         Abin Sur
# 3                         Agent R-7, Ravager of Worlds      Abomination
# 4                                                    -          Abraxas
# ..                                                 ...              ...
# 725                                           Hank Pym     Yellowjacket
# 726                                                  -  Yellowjacket II
# 727                                          Aurgelmir             Ymir
# 728                                                  -             Yoda
# 729                                                  -          Zatanna
#
#     Fuerza Potencia Velocidad
# 0      100       24        17
# 1       28      100        35
# 2       90       99        53
# 3       80       62        53
# 4       63      100        83
# ..     ...      ...       ...
# 725     10       12        12
# 726     10       31        35
# 727    100       98        27
# 728     52      100        33
# 729     10      100        23
#
# [730 rows x 5 columns]

# %%
# Out:
# 100.0

# %%
# Out:
# ID                    384
# Nombre          Kid Flash
# Inteligencia         25.0
# Fuerza                4.0
# Velocidad              92
# Name: 383, dtype: object
